# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd   
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/채소생산량_조미채소_2000-2019.csv", encoding='cp949')
data
# Out:
#         시도별        2000        2000.1        2001        2001.1        2001.2  \
# 0       시도별  대파:면적 (ha)  노지대파:면적 (ha)  대파:면적 (ha)  노지대파:면적 (ha)  시설대파:면적 (ha)
# 1         계       13768         13768       13519         12136          1383
# 2     서울특별시         185           185         289           201            88
# 3     부산광역시        1014          1014         995           908            87
# 4     대구광역시         489           489         430           387            43
# 5     인천광역시         353           353         361           323            38
# 6     광주광역시          63            63          73            68             5
# 7     대전광역시          50            50          66            44            22
# 8     울산광역시          40            40          34            33             1
# 9   세종특별자치시           -             -           -             -             -
# 10      경기도        2162          2162        2998          2252           746
# ...

# %%
data.columns
# Out:
# Index(['시도별', '2000', '2000.1', '2001', '2001.1', '2001.2', '2002', '2002.1',
#        '2002.2', '2003', '2003.1', '2003.2', '2004', '2004.1', '2004.2',
#        '2005', '2005.1', '2005.2', '2006', '2006.1', '2006.2', '2007',
#        '2007.1', '2007.2', '2008', '2008.1', '2008.2', '2009', '2009.1',
#        '2009.2', '2010', '2010.1', '2010.2', '2011', '2011.1', '2011.2',
#        '2012', '2012.1', '2012.2', '2013', '2013.1', '2013.2', '2014',
#        '2014.1', '2014.2', '2015', '2015.1', '2015.2', '2016', '2016.1',
#        '2016.2', '2017', '2017.1', '2017.2', '2018', '2018.1', '2018.2',
#        '2019', '2019.1', '2019.2'],
#       dtype='object')

# %%
data.columns = data.iloc[0]
data = pd.concat([data.iloc[2:,0],data.iloc[2:,3:]],axis=1)
data
# Out:
#         시도별 대파:면적 (ha) 노지대파:면적 (ha) 시설대파:면적 (ha) 대파:면적 (ha) 노지대파:면적 (ha)  \
# 2     서울특별시        289          201           88        286          158
# 3     부산광역시        995          908           87        866          839
# 4     대구광역시        430          387           43        360          318
# 5     인천광역시        361          323           38        382          349
# 6     광주광역시         73           68            5         22           22
# 7     대전광역시         66           44           22         61           44
# 8     울산광역시         34           33            1         30           30
# 9   세종특별자치시          -            -            -          -            -
# 10      경기도       2998         2252          746       3600         2580
# 11      강원도        394          373           21        523          509
# 12     충청북도        762          704           58        669          613
# 13     충청남도        772          710           62        769          688
# ...

# %%
data = data.reset_index(drop=True)

# %%
all_data = pd.DataFrame(columns=['시도별', '년', '월', '총생산량', '노지_생산량', '시설_생산량'])
geo = pd.DataFrame(data.iloc[:,0].reset_index(drop=True))
geo.columns = ['시도별']
geo
# Out:
#         시도별
# 0     서울특별시
# 1     부산광역시
# 2     대구광역시
# 3     인천광역시
# 4     광주광역시
# 5     대전광역시
# 6     울산광역시
# 7   세종특별자치시
# 8       경기도
# 9       강원도
# 10     충청북도
# 11     충청남도
# 12     전라북도
# 13     전라남도
# 14     경상북도
# 15     경상남도
# 16      제주도

# %%
all_data
# Out:
# Empty DataFrame
# Columns: [시도별, 년, 월, 총생산량, 노지_생산량, 시설_생산량]
# Index: []

# %%
# data.columns = data.iloc[0]
# data = data.drop(data.index[[0,1]]).reset_index(drop=True)
# data
# Out:
# 2     서울특별시   289   201   88   286   158   128   121    63   58  ...    3  \
# 0     대구광역시   430   387   43   360   318    42   327   283   44  ...    9
# 1     인천광역시   361   323   38   382   349    33   424   331   93  ...   34
# 2     광주광역시    73    68    5    22    22     0    12    12    0  ...    0
# 3     대전광역시    66    44   22    61    44    17    85    44   41  ...    2
# 4     울산광역시    34    33    1    30    30     0    35    35    0  ...    2
# 5   세종특별자치시     -     -    -     -     -     -     -     -    -  ...  120
# 6       경기도  2998  2252  746  3600  2580  1020  3184  2185  999  ...  764
# 7       강원도   394   373   21   523   509    14   478   438   40  ...   17
# 8      충청북도   762   704   58   669   613    56   731   676   55  ...   85
# 9      충청남도   772   710   62   769   688    81   820   722   98  ...   85
# 10     전라북도   971   875   96   928   842    86   727   628   99  ...  165
# 11     전라남도  3475  3448   27  3074  3041    33  3435  3392   43  ...   15
# ...

# %%
year = 2001
for i in range(1,58,3):
  new = pd.DataFrame(data.iloc[:,i:i+3])
  new.columns = ['총생산량', '노지_생산량', '시설_생산량']
  temp = pd.concat((geo, new), axis=1)
  temp['년'] = year
  year += 1
  for j in range(1,13):
    temp['월'] = j
    all_data = pd.concat([all_data, temp])
all_data.reset_index(drop=True)
# Out:
#         시도별     년   월  총생산량 노지_생산량 시설_생산량
# 0     서울특별시  2001   1   289    201     88
# 1     부산광역시  2001   1   995    908     87
# 2     대구광역시  2001   1   430    387     43
# 3     인천광역시  2001   1   361    323     38
# 4     광주광역시  2001   1    73     68      5
# ...     ...   ...  ..   ...    ...    ...
# 3871   전라북도  2019  12   915    682    233
# 3872   전라남도  2019  12  3741   3713     29
# 3873   경상북도  2019  12   795    658    137
# 3874   경상남도  2019  12   765    451    314
# 3875    제주도  2019  12   301    301      1
#
# [3876 rows x 6 columns]

# %%
all_data2 = all_data.replace('-', np.NaN)
all_data2
# Out:
#       시도별     년   월  총생산량 노지_생산량 시설_생산량
# 0   서울특별시  2001   1   289    201     88
# 1   부산광역시  2001   1   995    908     87
# 2   대구광역시  2001   1   430    387     43
# 3   인천광역시  2001   1   361    323     38
# 4   광주광역시  2001   1    73     68      5
# ..    ...   ...  ..   ...    ...    ...
# 12   전라북도  2019  12   915    682    233
# 13   전라남도  2019  12  3741   3713     29
# 14   경상북도  2019  12   795    658    137
# 15   경상남도  2019  12   765    451    314
# 16    제주도  2019  12   301    301      1
#
# [3876 rows x 6 columns]

# %%
all_data2.to_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(process)/대파_노지_시설_생산량_2001-2019.csv")

# %%
data = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/채소생산량_조미채소_2000-2019.csv",encoding='cp949')
data
# Out:
#         시도별        2000        2000.1        2001        2001.1        2001.2  \
# 0       시도별  대파:면적 (ha)  노지대파:면적 (ha)  대파:면적 (ha)  노지대파:면적 (ha)  시설대파:면적 (ha)
# 1         계       13768         13768       13519         12136          1383
# 2     서울특별시         185           185         289           201            88
# 3     부산광역시        1014          1014         995           908            87
# 4     대구광역시         489           489         430           387            43
# 5     인천광역시         353           353         361           323            38
# 6     광주광역시          63            63          73            68             5
# 7     대전광역시          50            50          66            44            22
# 8     울산광역시          40            40          34            33             1
# 9   세종특별자치시           -             -           -             -             -
# 10      경기도        2162          2162        2998          2252           746
# ...

# %%
data.columns
# Out:
# Index(['시도별', '2000', '2000.1', '2001', '2001.1', '2001.2', '2002', '2002.1',
#        '2002.2', '2003', '2003.1', '2003.2', '2004', '2004.1', '2004.2',
#        '2005', '2005.1', '2005.2', '2006', '2006.1', '2006.2', '2007',
#        '2007.1', '2007.2', '2008', '2008.1', '2008.2', '2009', '2009.1',
#        '2009.2', '2010', '2010.1', '2010.2', '2011', '2011.1', '2011.2',
#        '2012', '2012.1', '2012.2', '2013', '2013.1', '2013.2', '2014',
#        '2014.1', '2014.2', '2015', '2015.1', '2015.2', '2016', '2016.1',
#        '2016.2', '2017', '2017.1', '2017.2', '2018', '2018.1', '2018.2',
#        '2019', '2019.1', '2019.2'],
#       dtype='object')

# %%
data_2002 = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/수입량_노지채소_2002.csv", encoding='cp949')
data_2003_2012 = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/수입량_노지채소_2003-2012.csv", encoding='cp949')
data_2013_2019 = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/수입량_노지채소_2013-2019.csv", encoding='cp949')
display(data_2002, data_2003_2012, data_2013_2019)
# Out:
#          비목명별(1)  2002
# 0        비목명별(1)    대파
# 1     주산물수량 (kg)  3279
# 2  농가수취가격 (원/kg)   762
#          비목명별(1)  2003  2004  2005  2006  2007  2008  2009  2010  2011  2012
# 0        비목명별(1)    대파    대파    대파    대파    대파    대파    대파    대파    대파    대파
# 1     주산물수량 (kg)  3148  3397  3504  3249  3409  3398  3433  3450  3473  3333
# 2  농가수취가격 (원/kg)  1096   591   867   761   910   565   725  1157   639  1142
#          비목명별(1)  2013  2014  2015  2016  2017  2018  2019
# 0        비목명별(1)    대파    대파    대파    대파    대파    대파    대파
# 1     주산물수량 (kg)  3516  3442  3724  3576  3393  2961  3312
# 2  농가수취가격 (원/kg)   863   777   978  1140   977   989   855

# %%
all_data_income = pd.concat([data_2002.iloc[1:,:],data_2003_2012.iloc[1:,1:], data_2013_2019.iloc[1:,1:]], axis=1) 
all_data_income = all_data_income.transpose()
all_data_income.columns = ['주산물수량','농가수취가격']
all_data_income = all_data_income.drop(all_data_income.index[0])
all_data_income['년'] = all_data_income.index.astype(int)
all_data_income['주산물수량'] = all_data_income['주산물수량'].astype(int)
all_data_income['농가수취가격'] = all_data_income['농가수취가격'].astype(int)
# all_data_income['총수입'] = all_data_income['주산물수량'] * all_data_income['농가수취가격']
all_data_income
# Out:
#       주산물수량  농가수취가격     년
# 2002   3279     762  2002
# 2003   3148    1096  2003
# 2004   3397     591  2004
# 2005   3504     867  2005
# 2006   3249     761  2006
# 2007   3409     910  2007
# 2008   3398     565  2008
# 2009   3433     725  2009
# 2010   3450    1157  2010
# 2011   3473     639  2011
# 2012   3333    1142  2012
# 2013   3516     863  2013
# 2014   3442     777  2014
# 2015   3724     978  2015
# 2016   3576    1140  2016
# 2017   3393     977  2017
# 2018   2961     989  2018
# 2019   3312     855  2019

# %%
final_data = pd.DataFrame(columns=['년','월','주산물수량', '농가수취가격'])
for i in range(18):
  for j in range(1,13):
    all_data_income['월'] = j
    final_data = final_data.append(all_data_income.iloc[i])
final_data['총수입량'] = final_data['농가수취가격'] * final_data['주산물수량']
# for col in final_data.columns:
#   final_data[col] = final_data[col].astype(int)
final_data
# Out:
#          년   월 주산물수량 농가수취가격     총수입량
# 2002  2002   1  3279    762  2498598
# 2002  2002   2  3279    762  2498598
# 2002  2002   3  3279    762  2498598
# 2002  2002   4  3279    762  2498598
# 2002  2002   5  3279    762  2498598
# ...    ...  ..   ...    ...      ...
# 2019  2019   8  3312    855  2831760
# 2019  2019   9  3312    855  2831760
# 2019  2019  10  3312    855  2831760
# 2019  2019  11  3312    855  2831760
# 2019  2019  12  3312    855  2831760
#
# [216 rows x 5 columns]

# %%
final_data2 = pd.DataFrame()
for i in range(216):
  temp = pd.DataFrame()
  for j in range(17):
    temp = temp.append(final_data.iloc[i])
  temp = temp.reset_index(drop=True)
  final = pd.concat([geo, temp], axis=1, ignore_index=True)
  final_data2 = final_data2.append(final)
final_data2.columns = ['시도별', '년', '월', '주산물수량', '농가수취가격', '총수입량']
for col in final_data2.columns:
  if final_data2[col].dtypes == float:
    final_data2[col] = final_data2[col].astype(int)
final_data2
# Out:
#       시도별     년   월  주산물수량  농가수취가격     총수입량
# 0   서울특별시  2002   1   3279     762  2498598
# 1   부산광역시  2002   1   3279     762  2498598
# 2   대구광역시  2002   1   3279     762  2498598
# 3   인천광역시  2002   1   3279     762  2498598
# 4   광주광역시  2002   1   3279     762  2498598
# ..    ...   ...  ..    ...     ...      ...
# 12   전라북도  2019  12   3312     855  2831760
# 13   전라남도  2019  12   3312     855  2831760
# 14   경상북도  2019  12   3312     855  2831760
# 15   경상남도  2019  12   3312     855  2831760
# 16    제주도  2019  12   3312     855  2831760
#
# [3672 rows x 6 columns]

# %%
final_data2 = final_data2.reset_index(drop=True)
final_data2
# Out:
#         시도별     년   월  주산물수량  농가수취가격     총수입량
# 0     서울특별시  2002   1   3279     762  2498598
# 1     부산광역시  2002   1   3279     762  2498598
# 2     대구광역시  2002   1   3279     762  2498598
# 3     인천광역시  2002   1   3279     762  2498598
# 4     광주광역시  2002   1   3279     762  2498598
# ...     ...   ...  ..    ...     ...      ...
# 3667   전라북도  2019  12   3312     855  2831760
# 3668   전라남도  2019  12   3312     855  2831760
# 3669   경상북도  2019  12   3312     855  2831760
# 3670   경상남도  2019  12   3312     855  2831760
# 3671    제주도  2019  12   3312     855  2831760
#
# [3672 rows x 6 columns]

# %%
final_data2.to_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(process)/대파_수입량_2002-2019.csv")

# %%
house_harvest_data = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/시설작물_재배면적_2006-2019.csv", encoding='cp949')
house_harvest_data
# Out:
#      시도별(1)  2006 2006.1 2006.2  2007 2007.1 2007.2  2008 2008.1 2008.2  ...  \
# 0    시도별(1)    대파     대파     대파    대파     대파     대파    대파     대파     대파  ...
# 1    시도별(1)    합계      논      밭    합계      논      밭    합계      논      밭  ...
# 2         계  1600    323   1277  1480    285   1195  1436    218   1218  ...
# 3     서울특별시    20      0     20     5      0      5    27      0     27  ...
# 4     부산광역시    40     32      8    24     17      7     3      0      3  ...
# 5     대구광역시    32      7     25    29      0     29    35      9     26  ...
# 6     인천광역시    21      1     20    26      0     26    61      0     61  ...
# 7     광주광역시     0      0      0     2      2      0     0      0      0  ...
# 8     대전광역시     1      0      1     2      0      2     0      0      0  ...
# 9     울산광역시     2      0      2     0      0      0     0      0      0  ...
# 10  세종특별자치시     -      -      -     -      -      -     -      -      -  ...
# ...

# %%
oil_data = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/주유소_지역별_평균판매가격.csv")
oil_data = oil_data.iloc[7:,:]
oil_data.columns = oil_data.iloc[0]
oil_data = oil_data.iloc[1:,:]
oil_data
# Out:
# 7          구분       서울       부산       대구       인천       광주       대전       울산  \
# 8    2000년01월  1228.97   1212.2  1201.29  1225.15  1216.67  1198.04  1220.88
# 9    2000년02월  1226.76  1199.35  1192.29  1222.05  1211.17  1186.54   1195.3
# 10   2000년03월  1225.63  1196.22   1196.7  1220.31  1203.25  1190.82  1202.05
# 11   2000년04월  1201.18  1187.88  1178.83  1199.34  1182.23  1154.48   1186.5
# 12   2000년05월   1201.9  1181.02  1185.05  1198.49  1177.68  1151.74  1173.68
# ..        ...      ...      ...      ...      ...      ...      ...      ...
# 243  2019년08월  1589.33  1476.72  1463.37  1491.56  1469.82  1487.84  1469.27
# 244  2019년09월  1633.23  1514.94  1498.92  1536.46  1504.01  1531.59  1507.73
# 245  2019년10월  1634.78  1523.02  1509.57  1542.88  1517.43  1540.59  1516.32
# 246  2019년11월  1620.79  1515.09  1506.61  1537.81  1515.83  1532.93  1514.85
# 247  2019년12월  1630.96  1527.78   1522.3  1553.71  1533.05  1551.97  1531.26
#
# ...

# %%
oil_data = oil_data.transpose()
# oil_data.columns = oil_data.iloc[0]
# oil_data = oil_data.iloc[1:,:]
oil_data = oil_data.reset_index()

# %%
oil_data
# Out:
#    7         8         9         10        11        12        13        14   \
# 0   구분  2000년01월  2000년02월  2000년03월  2000년04월  2000년05월  2000년06월  2000년07월
# 1   서울   1228.97   1226.76   1225.63   1201.18    1201.9    1264.1    1262.5
# 2   부산    1212.2   1199.35   1196.22   1187.88   1181.02   1245.85   1240.45
# 3   대구   1201.29   1192.29    1196.7   1178.83   1185.05   1235.18   1229.38
# 4   인천   1225.15   1222.05   1220.31   1199.34   1198.49   1257.41   1258.25
# 5   광주   1216.67   1211.17   1203.25   1182.23   1177.68   1235.17    1233.9
# 6   대전   1198.04   1186.54   1190.82   1154.48   1151.74   1233.02   1213.81
# 7   울산   1220.88    1195.3   1202.05    1186.5   1173.68   1239.69   1220.63
# 8   경기   1219.34    1215.6   1213.11   1193.12   1189.87   1246.82   1248.46
# 9   강원   1229.91   1227.31   1228.32   1207.51   1205.81   1268.55   1266.15
# 10  충북   1206.75   1202.18   1198.87   1176.02    1172.8    1232.9   1228.58
# ...

# %%
geo = oil_data.iloc[1:,0]

# %%
geo
# Out:
# 1     서울
# 2     부산
# 3     대구
# 4     인천
# 5     광주
# 6     대전
# 7     울산
# 8     경기
# 9     강원
# 10    충북
# 11    충남
# 12    전북
# 13    전남
# 14    경북
# 15    경남
# 16    제주
# 17    세종
# Name: 7, dtype: object

# %%
all_oil_data = pd.DataFrame(columns=['시도별', '년', '월', '유가'])
year = 2000
for i in range(1,241):
  temp = oil_data.iloc[1:,i]
  new = pd.concat([geo, oil_data.iloc[1:,i]], axis=1, ignore_index=True)
  new.columns = ['시도별', '유가']
  new['년'] = year
  if i % 12 == 0:
    new['월'] = 12
    year += 1
  else:
    new['월'] = i % 12
  all_oil_data = pd.concat([all_oil_data, new], ignore_index=True)
all_oil_data
# Out:
#      시도별     년   월       유가
# 0     서울  2000   1  1228.97
# 1     부산  2000   1   1212.2
# 2     대구  2000   1  1201.29
# 3     인천  2000   1  1225.15
# 4     광주  2000   1  1216.67
# ...   ..   ...  ..      ...
# 4075  전남  2019  12  1535.63
# 4076  경북  2019  12  1531.29
# 4077  경남  2019  12  1527.44
# 4078  제주  2019  12  1610.68
# 4079  세종  2019  12  1541.78
#
# [4080 rows x 4 columns]

# %%
all_oil_data = all_oil_data.replace(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주', '세종'],
                                    ['서울특별시','부산광역시','대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도', '경상남도', '제주', '세종특별자치시'])
all_oil_data
# Out:
#           시도별     년   월       유가
# 0       서울특별시  2000   1  1228.97
# 1       부산광역시  2000   1   1212.2
# 2       대구광역시  2000   1  1201.29
# 3       인천광역시  2000   1  1225.15
# 4       광주광역시  2000   1  1216.67
# ...       ...   ...  ..      ...
# 4075     전라남도  2019  12  1535.63
# 4076     경상북도  2019  12  1531.29
# 4077     경상남도  2019  12  1527.44
# 4078       제주  2019  12  1610.68
# 4079  세종특별자치시  2019  12  1541.78
#
# [4080 rows x 4 columns]

# %%
all_oil_data.to_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(process)/유가_200")

# %%
# oil_data.columns
# Out:
# Index([         7, '2000년01월', '2000년02월', '2000년03월', '2000년04월', '2000년05월',
#        '2000년06월', '2000년07월', '2000년08월', '2000년09월',
#        ...
#        '2019년03월', '2019년04월', '2019년05월', '2019년06월', '2019년07월', '2019년08월',
#        '2019년09월', '2019년10월', '2019년11월', '2019년12월'],
#       dtype='object', name='구분', length=241)

# %%
# oil_data['년'] = oil_data[7].str.split('년').str[0]
# oil_data['월'] = oil_data[7].str.split('년').str[1][:2]
# oil_data
# Out:
# 구분   7 2000년01월 2000년02월 2000년03월 2000년04월 2000년05월 2000년06월 2000년07월  \
# 0   서울  1228.97  1226.76  1225.63  1201.18   1201.9   1264.1   1262.5
# 1   부산   1212.2  1199.35  1196.22  1187.88  1181.02  1245.85  1240.45
# 2   대구  1201.29  1192.29   1196.7  1178.83  1185.05  1235.18  1229.38
# 3   인천  1225.15  1222.05  1220.31  1199.34  1198.49  1257.41  1258.25
# 4   광주  1216.67  1211.17  1203.25  1182.23  1177.68  1235.17   1233.9
# 5   대전  1198.04  1186.54  1190.82  1154.48  1151.74  1233.02  1213.81
# 6   울산  1220.88   1195.3  1202.05   1186.5  1173.68  1239.69  1220.63
# 7   경기  1219.34   1215.6  1213.11  1193.12  1189.87  1246.82  1248.46
# 8   강원  1229.91  1227.31  1228.32  1207.51  1205.81  1268.55  1266.15
# 9   충북  1206.75  1202.18  1198.87  1176.02   1172.8   1232.9  1228.58
# 10  충남  1232.39  1226.53  1222.75  1199.08  1193.92  1248.52  1248.88
# 11  전북  1217.68  1201.61  1205.33  1185.83  1176.04  1232.25  1230.16
# ...

# %%
minimum_wage = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/최저시급_2000-2019.csv", encoding="utf8")
minimum_wage
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN       2000       2001       2002       2003       2004
# 1     시간급 최저임금      1,600      1,865      2,100      2,275      2,510
# 2  전년대비 인상률(%)        4.9       16.6       12.6        8.3       10.3
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 11 Unnamed: 12  \
# 0       2005       2006       2007       2008  ...        2010        2011
# 1      2,840      3,100      3,480      3,770  ...       4,110       4,320
# 2       13.1        9.2       12.3        8.3  ...        2.75         5.1
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 0        2012        2013        2014        2015        2016        2017
# 1       4,580       4,860       5,210       5,580       6,030       6,470
# 2           6         6.1         7.2         7.1         8.1         7.3
#
#   Unnamed: 19 Unnamed: 20
# 0        2018        2019
# 1       7,530       8,350
# ...

# %%
minimum_wage = minimum_wage.transpose()
minimum_wage.columns = ['년', '최저임금', '전년대비 인상률(%)']
minimum_wage = minimum_wage.iloc[1:,:]
minimum_wage = minimum_wage.reset_index(drop=True)

# %%
minimum_wage = minimum_wage.iloc[:,:2]
minimum_wage
# Out:
#        년   최저임금
# 0   2000  1,600
# 1   2001  1,865
# 2   2002  2,100
# 3   2003  2,275
# 4   2004  2,510
# 5   2005  2,840
# 6   2006  3,100
# 7   2007  3,480
# 8   2008  3,770
# 9   2009  4,000
# 10  2010  4,110
# 11  2011  4,320
# 12  2012  4,580
# 13  2013  4,860
# 14  2014  5,210
# 15  2015  5,580
# 16  2016  6,030
# 17  2017  6,470
# 18  2018  7,530
# 19  2019  8,350

# %%
final_data = pd.DataFrame(columns = ['년', '월','최저임금'])
for i in range(20):
  for j in range(1,13):
    minimum_wage['월'] = j
    final_data = final_data.append(minimum_wage.iloc[i])
final_data
# Out:
#        년   월   최저임금
# 0   2000   1  1,600
# 0   2000   2  1,600
# 0   2000   3  1,600
# 0   2000   4  1,600
# 0   2000   5  1,600
# ..   ...  ..    ...
# 19  2019   8  8,350
# 19  2019   9  8,350
# 19  2019  10  8,350
# 19  2019  11  8,350
# 19  2019  12  8,350
#
# [240 rows x 3 columns]

# %%
geo
# Out:
#         시도별
# 0     서울특별시
# 1     부산광역시
# 2     대구광역시
# 3     인천광역시
# 4     광주광역시
# 5     대전광역시
# 6     울산광역시
# 7   세종특별자치시
# 8       경기도
# 9       강원도
# 10     충청북도
# 11     충청남도
# 12     전라북도
# 13     전라남도
# 14     경상북도
# 15     경상남도
# 16      제주도

# %%
final_data2 = pd.DataFrame()
for i in range(240):
  temp = pd.DataFrame()
  for j in range(17):
    temp = temp.append(final_data.iloc[i])
  temp = temp.reset_index(drop=True)
  final = pd.concat([geo, temp], axis=1, ignore_index=True)
  final_data2 = final_data2.append(final)
# final_data2.columns = ['시도별', '년', '월', '최저임금']

# %%
final_data2 = final_data2.reset_index(drop=True)
final_data2.columns= ['시도별', '년', '월', '최저임금']
final_data2['월'] = final_data2['월'].astype(int)
final_data2
# Out:
#         시도별     년   월   최저임금
# 0     서울특별시  2000   1  1,600
# 1     부산광역시  2000   1  1,600
# 2     대구광역시  2000   1  1,600
# 3     인천광역시  2000   1  1,600
# 4     광주광역시  2000   1  1,600
# ...     ...   ...  ..    ...
# 4075   전라북도  2019  12  8,350
# 4076   전라남도  2019  12  8,350
# 4077   경상북도  2019  12  8,350
# 4078   경상남도  2019  12  8,350
# 4079    제주도  2019  12  8,350
#
# [4080 rows x 4 columns]

# %%
final_data2.to_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(process)/최저임금_2000-2019")

# %%
price_high_daegu = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/가격/대파가격_상_대구.csv", encoding="cp949")
price_high_daejeon = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/가격/대파가격_상_대전.csv", encoding="cp949")
price_high_busan = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/가격/대파가격_상_부산.csv", encoding="cp949")
price_high_seoul = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/가격/대파가격_상_서울.csv", encoding="cp949")

price_low_daegu = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/가격/대파가격_중_대구.csv", encoding="cp949")
price_low_daejun = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/가격/대파가격_중_대전.csv", encoding="cp949")
price_low_busan = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/가격/대파가격_중_부산.csv", encoding="cp949")
price_low_seoul = pd.read_csv("/content/drive/Shareddrives/2022-1-인공지능/1. 데이터(raw data)/가격/대파가격_중_서울.csv", encoding="cp949")

# %%
display(price_high_daegu, price_high_daejeon, price_high_busan, price_high_seoul)
# Out:
#       구분     1월     2월     3월     4월     5월     6월     7월     8월     9월  \
# 0   2000  1,376  1,259  1,210  1,167  1,046  1,230  1,308  1,412  2,165
# 1   2001  1,243  1,050  1,094    860  1,029    946  1,094  1,439  1,450
# 2   2002  1,151  1,133  1,037    881  1,083  1,035  1,025  1,368  2,017
# 3   2003  1,614  2,065  2,350  1,945  1,832  1,461  1,455  1,647  2,038
# 4   2004  2,165  2,187  2,483  1,962  1,313  1,105  1,166  1,340  1,649
# 5   2005  1,375  1,437  1,304  1,091  1,038  1,178  1,283  1,826  2,236
# 6   2006  2,688  3,014  2,860  2,659  2,257  1,626  1,752  2,234  1,918
# 7   2007  1,298  1,395  1,334  1,205  1,298  1,578  1,692  1,865  2,348
# 8   2008  3,402  3,601  3,081  2,432  1,815  1,500  1,546  1,543  1,671
# 9   2009  1,517  1,616  1,482  1,470  1,494  2,021  2,091  2,353  2,418
# 10  2010  2,131  2,286  2,504  2,672  3,112  2,839  2,937  2,568  4,316
# 11  2011  4,225  4,353  3,588  2,388  1,657  1,568  1,426  1,762  2,213
# ...
